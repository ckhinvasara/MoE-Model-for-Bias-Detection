# %%
# %pip install translate
# %pip install py-translate
# Out:
# Collecting py-translate
#   Downloading py_translate-1.0.3-py2.py3-none-any.whl (61 kB)
# Installing collected packages: py-translate
# Successfully installed py-translate-1.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import translate

# %%
def merge_dfs(datasets):
    merged_df = pd.concat(datasets)
    return merged_df

# %%
def store_data(filepath, data):
    data.to_csv(filepath, index=False)

# %%
gen_data = pd.read_csv("Data/CDIAL-Bias-English/train/gender.csv", encoding='utf-8')
race_data = pd.read_csv("Data/CDIAL-Bias-English/train/race.csv", encoding='utf-8')
occ_data = pd.read_csv("Data/CDIAL-Bias-English/train/occupation.csv", encoding='utf-8')
reg_data = pd.read_csv("Data/CDIAL-Bias-English/train/region.csv", encoding='utf-8')

# %%
small_df = merge_dfs([gen_data[:200], race_data[:200], occ_data[:200], reg_data[:200]])
small_df
# Out:
#       topic    idx                                                  q  \
# 0    Gender  14550  What is it like for trans women to pretend to ...
# 1    Gender   6905         do some girls dislike the word "virtuous"?
# 2    Gender   7609  it realistic to ask girls in their 20s to be v...
# 3    Gender  13550      When did you feel discrimination against men?
# 4    Gender   8050     Is there a gay man who can tell his own story?
# ..      ...    ...                                                ...
# 195  region   3070  What do you think of Region discrimination or ...
# 196  region   3833      What do provincials think of Zhejiang people?
# 197  region   2709  How to get along with Northeasterners on the I...
# 198  region   3181  Why has the reputation of Henan people suddenl...
# 199  region   2104  Why are the vast majority of Northeasterners a...
#
#                                                      a  context  datatype  \
# 0     The phrase "pretend to be a boy" is interesting.        0         0
# 1    Because some people think that "virtuous" is s...        0         1
# 2    As long as you give enough money, don't say th...        0         1
# 3    The recent cargo lala, whether the deceased ju...        1         2
# 4    Thanks for the invitation. I was affected, I o...        0         0
# ..                                                 ...      ...       ...
# 195  Low quality cannot be discriminated against, b...        1         2
# 196  Just graduated and went to Hangzhou to work fo...        0         0
# 197  Northeastern. If you really want to get along ...        0         1
# 198  No reliable source of information], in order t...        0         0
# 199  I just came back from a trip to Chengdu in Dec...        0         0
#
#      attitude                       group
# 0           0                 Transgender
# 1           3        Disgust virtuousness
# 2           3        Disgust virtuousness
# 3           2  Discrimination against men
# 4           0                  Homosexual
# ..        ...                         ...
# 195         3       Region discrimination
# 196         0             Zhejiang people
# 197         2             Northeasterners
# 198         0                Henan people
# 199         0             Northeasterners
#
# [800 rows x 8 columns]

# %%
store_data("Data/CDIAL-Bias-English/train/small_df.csv", small_df)

# %%
import html
import re

def translate_df(data):
    
    translator = translate.translator()

    q_translated = []
    a_translated = []
    topic_translated = []
    group_translated = []

    topic_array = dict()
    for quest in data['topic']:
        if quest in topic_array:
            topic_translated.append(topic_array[quest])
        else:
            try:
                text = translator.translate(quest)
                TAG_RE = re.compile(r'<[^>]+>')
                text = re.sub(TAG_RE,"", text)
                topic_translated.append(text[:-1])
                topic_array[quest] = topic_translated[-1]
            except:
                topic_translated.append("")

    group_array = dict()
    for quest in data['group'][:100]:
        if quest in group_array:
            group_translated.append(group_array[quest])
        else:
            try:
                text = translator.translate(quest)
                TAG_RE = re.compile(r'<[^>]+>')
                text = re.sub(TAG_RE,"", text)
                group_translated.append(text)
                group_array[quest] = group_translated[-1]
            except:
                group_translated.append("")

    question_array = dict()
    for quest in data['q'][:100]:
        if quest in question_array:
            q_translated.append(question_array[quest])
        else:
            try:
                text = translator.translate(quest)
                TAG_RE = re.compile(r'<[^>]+>')
                text = re.sub(TAG_RE,"", text)
                q_translated.append(text)
                question_array[quest] = q_translated[-1]
            except:
                q_translated.append("")

    answer_array = dict()
    for quest in data['a']:
        if quest in answer_array:
            a_translated.append(answer_array[quest])
        else:
            try:
                text = translator.translate(quest)
                TAG_RE = re.compile(r'<[^>]+>')
                text = re.sub(TAG_RE,"", text)
                a_translated.append(text)
                answer_array[quest] = a_translated[-1]
            except:
                a_translated.append("")

    return [topic_translated, group_translated, q_translated, a_translated]

# %%
def get_translations(data):
    data['topic'], data['group'], data['q'], data['a'] = translate_df(data)
    return data

# %%
gen_data = get_translations(gen_data)
race_data = get_translations(race_data)
reg_data = get_translations(reg_data)
occ_data = get_translations(occ_data)

# %%
race_data[:5750]
# Out:
#                topic    idx  \
# 0     Ethnic culture  22105
# 1     Ethnic culture  19379
# 2           minority   5347
# 3     Ethnic culture  23402
# 4     Ethnic culture  19307
# ...              ...    ...
# 5745  Ethnic culture  20089
# 5746  Ethnic culture  16890
# 5747  Ethnic culture  15483
# 5748  Ethnic culture  24217
# 5749  Ethnic culture  23133
#
#                                                       q  \
# 0     Why does Negro's appearance not fit the aesthe...
# 1     Why did Jeremy Lin get raced in the NBA while ...
# 2                  Have you ever been discriminated by?
# 3     How to evaluate the suspension of a professor ...
# 4     Why did Jeremy Lin get raced in the NBA while ...
# ...                                                 ...
# 5745               Is China serious about racism today?
# 5746        What happens if the BLM movement continues?
# 5747            Should Asians support the BLM protests?
# 5748  What is the situation of "black life matter" i...
# 5749  How to evaluate the suspension of a professor ...
#
#                                                       a  context  datatype  \
# 0     I worked in Uganda, Africa for a year and was ...        0         0
# 1     Who specifically said that Yao Ming was not di...        1         2
# 2     I'm from Yunnan, and the most painful thing wh...        1         1
# 3     The professor was impartial and did nothing wr...        0         0
# 4     Don't say that in the basketball circle of the...        0         1
# ...                                                 ...      ...       ...
# 5745  Seriously, it's just that we can't detect it o...        1         2
# 5746  The United States has become South African and...        0         0
# 5747                 ASIAN(YELLOW)，LIVES，DO，NOT，MATTER。        0         0
# 5748  Today, United States is indeed caught in a hug...        0         1
# 5749  Undergraduate at UCLA, I took many Klein cours...        0         0
#
#       attitude                 group
# 0            0                 Negro
# 1            3                racism
# 2            3         Zhuang people
# 3            0                 Negro
# 4            3                racism
# ...        ...                   ...
# 5745         3                racism
# 5746         0  Asian discrimination
# 5747         0  Asian discrimination
# 5748         2                 Negro
# 5749         0                 Negro
#
# [5750 rows x 8 columns]

# %%
complete_df = merge_dfs([gen_data, occ_data, reg_data, race_data[:5750]])

# %%
store_data("Data/CDIAL-Bias-English/train/complete_df.csv", complete_df)
